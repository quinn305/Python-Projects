# %%
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

I = [-1.00E+13,-1.00E+12,-2.00E+12,-3.00E+12,-4.00E+12,-5.00E+12,-6.00E+12,-7.00E+12,-8.00E+12,-9.00E+12,0,1.00E+13,1.00E+12,2.00E+12,3.00E+12,4.00E+12,5.00E+12,6.00E+12,7.00E+12,8.00E+12,9.00E+12]
E = [4.29E-17,3.00E-17,3.03E-17,3.18E-17,3.14E-17,3.36E-17,3.40E-17,3.52E-17,3.88E-17,3.94E-17,3.18E-17,4.00E-17,3.09E-17,3.06E-17,3.06E-17,3.17E-17,3.23E-17,3.36E-17,3.47E-17,3.63E-17,4.00E-17]
plt.plot(I,E, 'ro')
plt.xlabel("I")
plt.ylabel("E")
# Out:
# Text(0, 0.5, 'E')

# %%
#What I need to automatically make graphs: 
#1. TableAdd(,) between each other TableAdd()
#2. ax_by_cz_MI = pd.read_csv(file path/ax_by_cz/energy_comp_mag.txt, usecols(current, M(y)))
#   ax_by_cz_EI = pd.read_csv(file path/ax_by_cz/energy_comp_mag.txt, usecols(current, E_total))
#3. ax_by_cz_MI.plot.scatter(x='Current',y='Magnetization')
#   ax_by_cz_ME.plot.scatter(x='Current',y='Total_Energy')
#4  plt.savefig("image_address.png")

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

data = np.loadtxt('')


I_1 = data[0]
M = data[1]
plt.plot(I_1, M,'r--')
plt.show()


I_2 = data[0]
E = data[6]
plt.plot(I_2, E,'r--')
plt.show()

# %%
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import os

cwd = os.getcwd() # Gives you your current working dir
os.chdir('/Users/quinncunningham/Documents/MUMAX_caluclations/test.out/')
cwd = os.getcwd() # Gives you your current working dir
print(cwd) 

data = np.loadtxt('table.txt')


x = data[:, 0]
y = data[:, 4]

aa = 2
bb = 3
cc = 1
ccurrent = 1e5

plt.plot(x,y, 'ro')
plt.xlabel("t")
plt.ylabel("E_J")
plt.savefig("plot.{}.{}.{}.{}.pdf".format(aa,bb,cc,ccurrent))
# Out:
# /Users/quinncunningham/Documents/MUMAX_caluclations/test.out

# %%
os.chdir('/')
qulist = #os.listdir()

for direct in qulist:
    os.chdir(direct)
    qulist2 = os.listdir()
# Out:
# home
# usr
# .Spotlight-V100
# net
# .DS_Store
# .PKInstallSandboxManager
# .PKInstallSandboxManager-SystemSoftware
# bin
# installer.failurerequests
# Network
# sbin
# .file
# etc
# var
# Library
# .Trashes
# System
# .OSInstallerMessages
# .fseventsd
# private
# .DocumentRevisions-V100
# .vol
# Users
# Applications
# dev
# Volumes
# tmp
# cores

# %%
import os
 
mainpath_1 = os.getcwd()
 
rem = 480
 
for folders in next(os.walk('.'))[1]: 
    os.chdir(folders)
    rem -= 1
    print("Currently executing for the case in:--> {}".format(folders))
    print("                          Spin-case:--> Up-Up ")
    os.system('python HoneyComb_uu.py')
    print("                          Spin-case:--> Down-Down")
    os.system('python HoneyComb_dd.py')
    print("                          Spin-case:--> Up-Down ")
    os.system('python HoneyComb_ud.py')
    print("                          Spin-case:--> Down-Up ")
    os.system('python HoneyComb_du.py')
    print("Remaining cases: {} ".format(rem))
    
    
    os.chdir(mainpath_1)

# %%
import os

mainpath_1 = os.getcwd()

rem_1 = 90


for folders in next(os.walk('.'))[1]:
    os.chdir(folders)
    rem_1 -= 1
    print("Currently in directory: {}".format(folders))
    data = np.loadtxt('table.txt')


    x = data[:, 0]
    y = data[:, 4]

    aa = 2
    bb = 3
    cc = 1

    ccurrent = 1e5

    plt.plot(x,y, 'ro')
    plt.xlabel("t")
    plt.ylabel("E_J")
    plt.savefig("plot.{}.{}.{}.{}.pdf".format(aa,bb,cc,ccurrent))
    
    os.chdir(mainpath_1)

# %%
import os

mainpath_1 = os.getcwd()

rem_1 = 90


for folders in next(os.walk('.'))[1]:
    os.chdir(folders)
    rem_1 -= 1
    print("Currently in directory: {}".format(folders))
    data = np.loadtxt('table.txt')


    x = data[:, 0]
    y = data[:, 4]

 
    plt.plot(x,y, 'ro')
    plt.xlabel("t")
    plt.ylabel("E_J")
    plt.savefig("plot.{}.pdf".format(folders))
    
    os.chdir(mainpath_1)

# %%
import os
os.getcwd()
os.chdir('/home/qfcp93/data/mumax_new_4e6')
next(os.walk('.'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-ae7b0e4b5589> in <module>
#       1 import os
#       2 os.getcwd()
# ----> 3 os.chdir('/home/qfcp93/data/mumax_new_4e6')
#       4 next(os.walk('.'))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/qfcp93/data/mumax_new_4e6'

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
mainpath_1 = '/Volumes/Q_thumb/PYTHON_TEST_MUMAX'
os.chdir(mainpath_1)

for lattices in next(os.walk('.'))[1]:
      if lattices[0] == 'a':
                os.chdir(lattices)
                mainpath_2 = os.getcwd()
                print("Currently in directory: {}".format(os.getcwd())) 
                fig = plt.figure( figsize = (20,7) )
                for folders in next(os.walk('.'))[1]:
                    if folders[0] == 'c':
                        os.chdir(folders)
                        #rem_1 -= 1
                        #print("Currently in directory: {}".format(os.getcwd()))
                        os.chdir('./test.out')
                        data = np.loadtxt('table.txt')

                        x = data[:, 0]
                        y = data[:, 4]

                        plt.plot(x,y, 'o-', label='{}'.format(folders))
                        plt.xlabel("t")
                        plt.ylabel("E_J")
                        #plt.savefig("plot.{}.pdf".format(folders))
                        plt.legend()
                        os.chdir(mainpath_2)
                plt.show()        
                os.chdir(mainpath_1)
# Out:
# Currently in directory: /Volumes/Q_thumb/PYTHON_TEST_MUMAX/a9_b3_c2
# Currently in directory: /Volumes/Q_thumb/PYTHON_TEST_MUMAX/a9_b3_c3

# %%
# Out:
# '/Users/quinncunningham'
